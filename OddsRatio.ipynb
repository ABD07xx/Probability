# %%
import pandas as pd
import statsmodels.api as sm

# %%
# Create a dataframe with the data
data = {'Cancer': [1, 1, 0, 1, 1, 1, 0, 0, 1, 0],
        'Smoker': [1, 1, 0, 1, 0, 1, 0, 0, 1, 0]}
df = pd.DataFrame(data)

# %%
# Fit the logistic regression model
logit_model = sm.Logit(df['Cancer'], df['Smoker'])
result = logit_model.fit()
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.346574
#          Iterations: 35
# C:\Users\Abdullah Fazili\anaconda3\lib\site-packages\statsmodels\base\model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Print the odds ratio
print(result.params)
# Out:
# Smoker    31.787724
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df)
plt.legend
# Out:
# [<matplotlib.lines.Line2D at 0x222b3a45970>,
#  <matplotlib.lines.Line2D at 0x222b3a45a90>]
